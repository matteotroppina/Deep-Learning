# %%
from phi.torch.flow import *
import numpy as np
import warnings
warnings.filterwarnings("ignore")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from phi.torch.flow import *
#       2 import numpy as np
#       3 import warnings
#
# File ~/anaconda3/lib/python3.11/site-packages/phi/torch/__init__.py:9
#       1 """
#       2 PyTorch integration.
#       3
#    (...)
#       7 To make PyTorch the default backend, import `phi.torch.flow`.
#       8 """
# ----> 9 from phiml.backend.torch import TORCH
#      11 __all__ = [key for key in globals().keys() if not key.startswith('_')]
#
# File ~/anaconda3/lib/python3.11/site-packages/phiml/backend/torch/__init__.py:6
#       1 """
#       2 PyTorch integration.
#       3 """
#       4 from ._torch_backend import TorchBackend as _TorchBackend
# ----> 6 TORCH = _TorchBackend()
#       7 """ Backend for PyTorch operations. """
#       9 __all__ = [key for key in globals().keys() if not key.startswith('_')]
#
# File ~/anaconda3/lib/python3.11/site-packages/phiml/backend/torch/_torch_backend.py:23, in TorchBackend.__init__(self)
#      21 devices = [ComputeDevice(self, "CPU", 'CPU', cpu.memory, cpu.processor_count, cpu.description, ref='cpu')]
#      22 for index in range(torch.cuda.device_count()):
# ---> 23     properties = torch.cuda.get_device_properties(index)
#      24     devices.append(ComputeDevice(self, properties.name, 'GPU', properties.total_memory, properties.multi_processor_count, f"compute capability {properties.major}.{properties.minor}", f'cuda:{index}'))
#      25 Backend.__init__(self, 'torch', devices, devices[1 if len(devices) > 1 else 0])
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/cuda/__init__.py:444, in get_device_properties(device)
#     434 def get_device_properties(device: _device_t) -> _CudaDeviceProperties:
#     435     r"""Get the properties of a device.
#     436
#     437     Args:
#    (...)
#     442         _CudaDeviceProperties: the properties of the device
#     443     """
# --> 444     _lazy_init()  # will define _get_device_properties
#     445     device = _get_device_index(device, optional=True)
#     446     if device < 0 or device >= device_count():
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/cuda/__init__.py:293, in _lazy_init()
#     291 if "CUDA_MODULE_LOADING" not in os.environ:
#     292     os.environ["CUDA_MODULE_LOADING"] = "LAZY"
# --> 293 torch._C._cuda_init()
#     294 # Some of the queued calls may reentrantly call _lazy_init();
#     295 # we need to just return without initializing in that case.
#     296 # However, we must not let any *other* threads in!
#     297 _tls.is_initializing = True
#
# RuntimeError: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero.

# %% [markdown]
# # Sphere Packing

# %% [markdown]
# ## 1. Setup

# %%
domain_size = 100
num_spheres = 1000
r1 = 0.7
r2 = 1

radii_list = []

#define list of radius (half spheres with R=1 and half R=07)
for i in range(num_spheres // 2):
    radii_list.append(r1)
for i in range(num_spheres // 2):
    radii_list.append(r2)

#define list of random locations
def locate_balls(domain_size):
    location_list = []
    for i in range(num_spheres):
        location_list.append( (math.random_uniform()*domain_size, math.random_uniform()*domain_size) )
    return location_list

location_list = locate_balls(domain_size)

radii = math.stack(radii_list, instance('spheres'))
initial_location = math.stack(location_list, instance('spheres'))

vis.plot(Sphere(x = initial_location[0], y = initial_location[1], radius=radii * math.sqrt(2)), lib='matplotlib')  

# location1 = math.random_uniform(channel(vector='x,y'), instance(spheres=nums_spheres // 2), low=0, high=domain_size)
# location2 = math.random_uniform(channel(vector='x,y'), instance(spheres=nums_spheres // 2), low=0, high=domain_size)
# spheres1 = Sphere(location1, radius=r1)
# spheres2 = Sphere(location2, radius=r2)
# vis.plot(concat(spheres1, spheres2), dim='spheres')

# %% [markdown]
# ## 2. Energy Function

# %%
eps = 1e-10
def energy_function(location):
    # Adjust location to stay within domain boundaries
    location = location - math.floor(location / domain_size) * domain_size
    
    dx = location - math.rename_dims(location, 'spheres', 'others')
    dx = dx + eps * math.ones_like(dx)
    
    dx_r = math.vec_squared(dx + tensor([1,0]) * math.ones_like(dx) * domain_size) ** 0.5 
    dx_l = math.vec_squared(dx + tensor([-1,0]) * math.ones_like(dx) * domain_size) ** 0.5
    
    dx_u = math.vec_squared(dx + tensor([0,1]) * math.ones_like(dx) * domain_size) ** 0.5
    dx_d = math.vec_squared(dx + tensor([0,-1]) * math.ones_like(dx) * domain_size) ** 0.5
    
    dx_ru = math.vec_squared(dx + tensor([1,1]) * math.ones_like(dx) * domain_size) ** 0.5
    dx_lu = math.vec_squared(dx + tensor([-1,1]) * math.ones_like(dx) * domain_size) ** 0.5
    
    dx_rd = math.vec_squared(dx + tensor([1,-1]) * math.ones_like(dx) * domain_size) ** 0.5
    dx_ld = math.vec_squared(dx + tensor([-1,-1]) * math.ones_like(dx) * domain_size) ** 0.5

    dx = math.vec_squared(dx) ** 0.5
    distance = math.min([dx, dx_l, dx_r, dx_u, dx_d, dx_ru, dx_lu, dx_rd, dx_ld],dim='0')
    
    #Computing overlap
    energy = math.maximum(radii + math.rename_dims(radii,'spheres','others') - distance, 0)
    
    distance = math.ones_like(distance) - tensor(np.eye(num_spheres), instance('spheres','others'))
    
    energy *= math.divide_no_nan(energy, distance)
    system_energy = math.sum(energy)
    
    return system_energy

# %%
def loss_function(location):
    energy = energy_function(location)
    return math.l2_loss(energy - 0)
    
print(f'Initial Energy: {energy_function(initial_location)}')
print(f'Initial Loss: {loss_function(initial_location)}')
# Out:
# Initial Energy: 445.31964
# Initial Loss: 99154.79

# %%
learning_rate = 1e-5
max_iterations = 2000

def gradient_descent_optimization(location):
    for i in range(max_iterations):
        gradient_func = math.functional_gradient(loss_function)
        loss, (gradients,) = gradient_func(location)
        if loss.native() < 0.1:
            break
        location  -= learning_rate * gradients
    return location - math.floor(location / domain_size) * domain_size

# %%
location = initial_location
optimized_location = gradient_descent_optimization(location)
print(f'Final Energy (Gradient Descent): {energy_function(optimized_location)}')

vis.plot(Sphere(x=optimized_location[0], y=optimized_location[1], radius=radii* math.sqrt(2)), lib='matplotlib')
# Out:
# Final Energy (Gradient Descent): 5.3704166

# %%
location = initial_location
optimized_location = math.minimize(energy_function, Solve('L-BFGS-B', 0, 1e-5, max_iterations=1000, x0=location))
print(f'Final Energy (SciPy L-BFGS-B): {energy_function(optimized_location)}')

vis.plot(Sphere(x=optimized_location[0], y=optimized_location[1], radius=radii* math.sqrt(2)), lib='matplotlib')
# Out:
# Final Energy (SciPy L-BFGS-B): 3.5461454e-08

# %%
def find_smallest_domain(initial_domain_size):
    domain_size = initial_domain_size
    while True:
        location_list = []
        location_list = locate_balls(domain_size)
        location = math.stack(location_list, instance('spheres'))
        optimized_location = math.minimize(energy_function, Solve('L-BFGS-B', 0, 1e-5, max_iterations=1000, x0=location))
        print(energy_function(optimized_location))
        print(domain_size)
        if energy_function(optimized_location).native() > 0.01:
            break
        domain_size -= 1
    return domain_size

domain_size = 100
smallest_domain_size = find_smallest_domain(domain_size)
print(f'Smallest domain size: {smallest_domain_size}')
# Out:
# 0.0
# 100
# 1.7763568e-11
# 99
# 5.570655e-12
# 98
# 1.678302e-10
# 97
# 1.0152519e-09
# 96
# 1.07149845e-10
# 95
# 7.570384e-07
# 94
# 0.0
# 93
# 5.570655e-12
# 92
# 3.6834535e-11
# 91
# 2.6110618e-07
# 90
# 1.8242758e-09
# 89
# 5.570655e-12
# 88
# 1.5429862e-09
# 87
# 1.1107049e-06
# 86
# 1.179989e-06
# 85
# 3.5115875e-07
# 84
# 1.9936482e-07
# 83
# 6.058775e-07
# 82
# 8.504259e-09
# 81
# 6.429036e-08
# 80
# 0.0
# 79
# 9.80703e-08
# 78
# 9.29067e-08
# 77
# 4.839022e-07
# 76
# 0.0
# 75
# 0.0
# 74
# 5.186887e-06
# 73
# 1.0524802e-06
# 72
# 2.3970392e-07
# 71
# 1.3814625e-07
# 70
# 1.7856735e-08
# 69
# 4.348916e-07
# 68
# 4.6087845e-07
# 67
# 1.0661264e-06
# 66
# 2.953203e-06
# 65
# 2.2527868e-06
# 64
# 1.2433667e-05
# 63
# 1.4737082e-06
# 62
# 1.7472287e-06
# 61
# 1.029696e-06
# 60
# 1.9632926e-06
# 59
# 3.6468516e-06
# 58
# 2.4451601e-06
# 57
# 2.6463674e-06
# 56
# 4.6227738e-06
# 55
# 4.2198935e-06
# 54
# 3.7137818e-06
# 53
# 2.7189362e-06
# 52
# 3.5799246e-06
# 51
# 5.513691e-06
# 50
# 4.569146e-06
# 49
# 6.006474e-07
# 48
# 5.695656e-07
# 47
# 1.5406746e-07
# 46
# 5.294636e-07
# 45
# 3.2945172e-07
# 44
# 3.6634674e-07
# 43
# 1.1787506e-08
# 42
# 5.6807608e-09
# 41
# 2.307612e-07
# 40
# 9.4268216e-08
# 39
# 1.1401111e-05
# 38
# 2.405005e-06
# 37
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 16
#      13     return domain_size
#      15 domain_size = 100
# ---> 16 smallest_domain_size = find_smallest_domain(domain_size)
#      17 print(f'Smallest domain size: {smallest_domain_size}')
#
# Cell In[13], line 5, in find_smallest_domain(initial_domain_size)
#       3 while True:
#       4     location_list = []
# ----> 5     location_list = locate_balls(domain_size)
#       6     location = math.stack(location_list, instance('spheres'))
#       7     optimized_location = math.minimize(energy_function, Solve('L-BFGS-B', 0, 1e-5, max_iterations=1000, x0=location))
#
# Cell In[2], line 18, in locate_balls(domain_size)
#      16 location_list = []
#      17 for i in range(num_spheres):
# ---> 18     location_list.append( (math.random_uniform()*domain_size, math.random_uniform()*domain_size) )
#      19 return location_list
#
# File ~/anaconda3/lib/python3.11/site-packages/phiml/math/_tensors.py:617, in Tensor.__mul__(self, other)
#     616 def __mul__(self, other):
# --> 617     return self._op2(other, lambda x, y: x * y, lambda x, y: choose_backend(x, y).mul(x, y), 'mul', '*')
#
# File ~/anaconda3/lib/python3.11/site-packages/phiml/math/_tensors.py:1304, in NativeTensor._op2(self, other, operator, native_function, op_name, op_symbol, switch_args)
#    1302     natives = natives[::-1]
#    1303 result_tensor = native_function(*natives)
# -> 1304 return NativeTensor(result_tensor, broadcast_shape, self._shape & other_tensor._shape)
#
# File ~/anaconda3/lib/python3.11/site-packages/phiml/math/_shape.py:679, in Shape.__and__(self, other)
#     678 def __and__(self, other):
# --> 679     return merge_shapes(self, other)
#
# File ~/anaconda3/lib/python3.11/site-packages/phiml/math/_shape.py:1732, in merge_shapes(order, allow_varying_sizes, *objs)
#    1730 type_group = dim_type(shapes[0])
#    1731 for sh in shapes[1:]:
# -> 1732     sh = dim_type(sh)
#    1733     for dim in sh:
#    1734         if dim not in type_group:
#
# File ~/anaconda3/lib/python3.11/site-packages/phiml/math/_shape.py:1468, in spatial(*args, **dims)
#    1437 """
#    1438 Returns the spatial dimensions of an existing `Shape` or creates a new `Shape` with only spatial dimensions.
#    1439
#    (...)
#    1465     `Shape` containing only dimensions of type spatial.
#    1466 """
#    1467 from .magic import Shaped
# -> 1468 if all(isinstance(arg, str) for arg in args) or dims:
#    1469     return _construct_shape(SPATIAL_DIM, *args, **dims)
#    1470 elif len(args) == 1 and isinstance(args[0], Shape):
#
# KeyboardInterrupt:

# %%
domain_size = 53
location_list = locate_balls(domain_size)
location = math.stack(location_list, instance('spheres'))
optimized_location = math.minimize(energy_function, Solve('L-BFGS-B', 0, 1e-5, max_iterations=1000, x0=location))
print(f'Final Energy (Gradient Descent): {energy_function(optimized_location)}')

vis.plot(Sphere(x=optimized_location[0], y=optimized_location[1], radius=radii), lib='matplotlib')
# Out:
# Final Energy (Gradient Descent): 0.002299325

# %%
domain_size = 52
location_list = locate_balls(domain_size)
location = math.stack(location_list, instance('spheres'))
optimized_location = math.minimize(energy_function, Solve('L-BFGS-B', 0, 1e-5, max_iterations=1000, x0=location))
print(f'Final Energy (Gradient Descent): {energy_function(optimized_location)}')

vis.plot(Sphere(x=optimized_location[0], y=optimized_location[1], radius=radii), lib='matplotlib')
# Out:
# ---------------------------------------------------------------------------
# NotConverged                              Traceback (most recent call last)
# Cell In[16], line 4
#       2 location_list = locate_balls(domain_size)
#       3 location = math.stack(location_list, instance('spheres'))
# ----> 4 optimized_location = math.minimize(energy_function, Solve('L-BFGS-B', 0, 1e-5, max_iterations=1000, x0=location))
#       5 print(f'Final Energy (Gradient Descent): {energy_function(optimized_location)}')
#       7 vis.plot(Sphere(x=optimized_location[0], y=optimized_location[1], radius=radii), lib='matplotlib')
#
# File ~/anaconda3/lib/python3.11/site-packages/phiml/math/_optimize.py:427, in minimize(f, solve)
#     425 for tape in _SOLVE_TAPES:
#     426     tape._add(solve, trj, result)
# --> 427 result.convergence_check(False)  # raises ConvergenceException
#     428 return x
#
# File ~/anaconda3/lib/python3.11/site-packages/phiml/math/_optimize.py:195, in SolveInfo.convergence_check(self, only_warn)
#     193     warnings.warn(self.msg, ConvergenceWarning)
#     194 else:
# --> 195     raise NotConverged(self)
#
# NotConverged: ['STOP: TOTAL NO. of ITERATIONS REACHED LIMIT']
